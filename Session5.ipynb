# %%
import numpy as np

def main():
    x_values = np.linspace(0, 2, 1000)

    print("x\t sin(x)")
    print("----------------")

    for x in x_values:
        print(x, "\t", np.sin(x))

if __name__ == "__main__":
    main()
# Out:
# x	 sin(x)
# ----------------
# 0.0 	 0.0
# 0.002002002002002002 	 0.0020020006646609234
# 0.004004004004004004 	 0.004003993305281807
# 0.006006006006006006 	 0.0060059698978547705
# 0.008008008008008008 	 0.008007922418436255
# 0.01001001001001001 	 0.010009842843179184
# 0.012012012012012012 	 0.012011723148365119
# 0.014014014014014014 	 0.014013555310436422
# 0.016016016016016016 	 0.016015331306028415
# 0.018018018018018018 	 0.01801704311200153
# 0.02002002002002002 	 0.020018682705473478
# 0.022022022022022022 	 0.0220202420638514
# 0.024024024024024024 	 0.024021713164864008
# 0.026026026026026026 	 0.026023087986593762
# 0.028028028028028028 	 0.028024358507509013
# 0.03003003003003003 	 0.030025516706496138
# 0.03203203203203203 	 0.03202655456289171
# 0.03403403403403403 	 0.034027464056514634
# 0.036036036036036036 	 0.036028237167698304
# 0.03803803803803804 	 0.038028865877322716
# 0.04004004004004004 	 0.04002934216684664
# 0.04204204204204204 	 0.04202965801833975
# ...
